# %%
# !python generate_dataset.py --config ../experiments/config_MiriGeminiHST_cloudfree.yaml --output-dir /home/mvasist/Documents/testing/simulations/cloudfree/ --batch-size 10 --array-index 11
# Out:
# Prior: 26 parameters
# IOStream.flush timed out
# Simulators: ['cloudfree_miri', 'cloudfree_hst', 'cloudfree_gemini']
# Theta mapper: 3 simulators, 26 merged params
# Output: /home/mvasist/Documents/testing
#
# Generating batch 11 for all simulators...
# ...
# 100%|████████████████████████████████████████| 9/9 [00:00<00:00, 3939.14pair/s]
#   Batch 11: 9 valid samples saved
#
# Dataset generation complete.

# %% [markdown]
# ## Aggregate

# %%
# !python generate_dataset.py --config ../experiments/config_MiriGeminiHST_cloudfree.yaml --output-dir /home/mvasist/Documents/testing/simulations/cloudfree --aggregate-only
# Out:
# Aggregating cloudfree_miri...
# 100%|█████████████████████████████████████| 87/87 [00:00<00:00, 59508.23pair/s]
#   Aggregated 10 files → /home/mvasist/Documents/testing/simulations/cloudfree/cloudfree_miri/train.h5 (87 samples)
# 100%|████████████████████████████████████████| 9/9 [00:00<00:00, 8850.82pair/s]
#   Aggregated 1 files → /home/mvasist/Documents/testing/simulations/cloudfree/cloudfree_miri/valid.h5 (9 samples)
# 100%|████████████████████████████████████████| 9/9 [00:00<00:00, 6448.37pair/s]
#   Aggregated 1 files → /home/mvasist/Documents/testing/simulations/cloudfree/cloudfree_miri/test.h5 (9 samples)
#
# Aggregating cloudfree_hst...
# 100%|█████████████████████████████████████| 87/87 [00:00<00:00, 21477.60pair/s]
#   Aggregated 10 files → /home/mvasist/Documents/testing/simulations/cloudfree/cloudfree_hst/train.h5 (87 samples)
# 100%|████████████████████████████████████████| 9/9 [00:00<00:00, 6615.62pair/s]
# ...

# %% [markdown]
# ## training

# %%
# !python training_evaluation.py --config-dir ../experiments/config_MiriGeminiHST_cloudfree.yaml --action train --name 3
# Out:
# /home/mvasist/miniconda3/envs/test/lib/python3.9/site-packages/wandb/apis/public.py:2997: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# Starting training!
# 2026-07-13 16:57:14,565 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-13 16:57:14,566 - sbi4atmret.runtime.setup_runtime - INFO - BUILDING CORE RUNTIME CONTEXT
# 2026-07-13 16:57:14,566 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-13 16:57:14,566 - sbi4atmret.runtime.setup_runtime - INFO - Using device: cpu
# 2026-07-13 16:57:14,566 - sbi4atmret.runtime.setup_runtime - INFO - Building simulators...
# ...

# %% [markdown]
# ## evaluation

# %%
# !python training_evaluation.py --config-dir ../experiments/config_MiriGeminiHST_cloudfree.yaml --action evaluate --name 3
# Out:
# ^C
# Traceback (most recent call last):
#   File "/home/mvasist/Documents/SBI4atmret/scripts/training_evaluation.py", line 11, in <module>
#     import torch
#   File "/home/mvasist/miniconda3/envs/test/lib/python3.9/site-packages/torch/__init__.py", line 1703, in <module>
#     from torch._tensor import Tensor  # usort: skip
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# KeyboardInterrupt

# %%
# !python training_evaluation.py --config-dir ../experiments/config_MiriGeminiHST_cloudfree.yaml --action evaluate --name 3 --checkpoint-path /home/mvasist/Documents/testing/runs/cloudfree/WISEJ1738/MIRI+HST+Gemini/3/checkpoints/checkpoint_400.pt
# Out:
# /home/mvasist/miniconda3/envs/test/lib/python3.9/site-packages/wandb/apis/public.py:2997: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# Using checkpoint: /home/mvasist/Documents/testing/runs/cloudfree/WISEJ1738/MIRI+HST+Gemini/3/checkpoints/checkpoint_400.pt
# Plotting and saving results!
# 2026-07-13 17:06:01,804 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-13 17:06:01,804 - sbi4atmret.runtime.setup_runtime - INFO - BUILDING CORE RUNTIME CONTEXT
# 2026-07-13 17:06:01,804 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-13 17:06:01,804 - sbi4atmret.runtime.setup_runtime - INFO - Using device: cpu
# ...

# %% [markdown]
# ## resume training

# %% [markdown]
# !python training_evaluation.py --config-dir ../experiments/config_MiriGeminiHST_cloudfree.yaml --action train --name 2 --resume --checkpoint-path /home/mvasist/Documents/testing/runs/cloudfree/WISEJ1738/MIRI+HST+Gemini/2/checkpoints/latest.pt

# %%
# python scripts/generate_dataset.py --config experiments/config_MiriGeminiHST_cloudfree_aws.yaml --output-dir ../simulations/cloudfree/ --batch-size 10 --array-index 666

# %%
# python scripts/generate_dataset.py --config experiments/config_MiriGeminiHST_cloudfree.yaml --output-dir ../simulations/cloudfree --parallel --n-array 300 --batch-size 4096 --cpus 2 --gpus 0 --ram 4GB --time 2-00:00:00
