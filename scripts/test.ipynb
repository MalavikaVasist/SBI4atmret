# %%
# !python generate_dataset.py --config ../experiments/config_MiriGeminiHST_cloudfree.yaml --output-dir /home/mvasist/Documents/testing --batch-size 5 --array-index 0
# Out:
# Prior: 26 parameters
# Simulators: ['cloudfree_miri', 'cloudfree_hst', 'cloudfree_gemini']
# Theta mapper: 3 simulators, 26 merged params
# Output: /home/mvasist/Documents/testing
#
# Generating batch 0 for all simulators...
#   WARNING: No valid samples for cloudfree_miri batch 0
#   WARNING: No valid samples for cloudfree_hst batch 0
#   WARNING: No valid samples for cloudfree_gemini batch 0
#   Batch 0: 0 valid samples saved
#
# Dataset generation complete.
