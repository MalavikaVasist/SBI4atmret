# %%
# !python generate_dataset.py --config ../experiments/config_MiriGeminiHST_cloudfree.yaml --output-dir /home/mvasist/Documents/testing --batch-size 10 --array-index 10
# Out:
# Prior: 26 parameters
# Simulators: ['cloudfree_miri', 'cloudfree_hst', 'cloudfree_gemini']
# Theta mapper: 3 simulators, 26 merged params
# Output: /home/mvasist/Documents/testing
#
# Generating batch 10 for all simulators...
# ...
# 100%|████████████████████████████████████████| 9/9 [00:00<00:00, 2817.91pair/s]
#   Batch 10: 9 valid samples saved
#
# Dataset generation complete.

# %%
# !python generate_dataset.py --config ../experiments/config_MiriGeminiHST_cloudfree.yaml --output-dir /home/mvasist/Documents/testing --aggregate-only
# Out:
# Aggregating cloudfree_miri...
# 100%|█████████████████████████████████████| 77/77 [00:00<00:00, 40649.64pair/s]
#   Aggregated 9 files → /home/mvasist/Documents/testing/cloudfree_miri/train.h5 (77 samples)
# 100%|██████████████████████████████████████| 10/10 [00:00<00:00, 8703.68pair/s]
#   Aggregated 1 files → /home/mvasist/Documents/testing/cloudfree_miri/valid.h5 (10 samples)
# 100%|████████████████████████████████████████| 9/9 [00:00<00:00, 9009.24pair/s]
#   Aggregated 1 files → /home/mvasist/Documents/testing/cloudfree_miri/test.h5 (9 samples)
#
# Aggregating cloudfree_hst...
# 100%|█████████████████████████████████████| 77/77 [00:00<00:00, 59619.98pair/s]
#   Aggregated 9 files → /home/mvasist/Documents/testing/cloudfree_hst/train.h5 (77 samples)
# 100%|██████████████████████████████████████| 10/10 [00:00<00:00, 8058.22pair/s]
#   Aggregated 1 files → /home/mvasist/Documents/testing/cloudfree_hst/valid.h5 (10 samples)
# ...

# %% [markdown]
# ## training

# %%
# !python training_evaluation.py --config-dir ../experiments/config_MiriGeminiHST_cloudfree.yaml --action train --checkpoint-path /home/mvasist/Documents/testing/runs/cloudfree/WISEJ1738/MIRI+HST+Gemini/1/

print('training')
# Out:
# /home/mvasist/miniconda3/envs/test/lib/python3.9/site-packages/wandb/apis/public.py:2997: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# Checkpoint found, resuming training!
# Starting training!
# 2026-07-12 17:40:30,342 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-12 17:40:30,342 - sbi4atmret.runtime.setup_runtime - INFO - BUILDING CORE RUNTIME CONTEXT
# 2026-07-12 17:40:30,342 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-12 17:40:30,343 - sbi4atmret.runtime.setup_runtime - INFO - Using device: cpu
# 2026-07-12 17:40:30,343 - sbi4atmret.runtime.setup_runtime - INFO - Building simulators...
# ...

# %% [markdown]
# ## evaluation

# %%
# !python training_evaluation.py --config-dir ../experiments/config_MiriGeminiHST_cloudfree.yaml --action evaluate --checkpoint-path /home/mvasist/Documents/testing/runs/cloudfree/WISEJ1738/MIRI+HST+Gemini/1/checkpoints/latest.pt
# Out:
# /home/mvasist/miniconda3/envs/test/lib/python3.9/site-packages/wandb/apis/public.py:2997: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# Checkpoint found, resuming training!
# Plotting and saving results!
# 2026-07-12 22:11:41,097 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-12 22:11:41,098 - sbi4atmret.runtime.setup_runtime - INFO - BUILDING CORE RUNTIME CONTEXT
# 2026-07-12 22:11:41,098 - sbi4atmret.runtime.setup_runtime - INFO - ============================================================
# 2026-07-12 22:11:41,098 - sbi4atmret.runtime.setup_runtime - INFO - Using device: cpu
# 2026-07-12 22:11:41,098 - sbi4atmret.runtime.setup_runtime - INFO - Building simulators...
# ...
